# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold




file = pd.read_csv("C:\\Users\\Jonathan\\Downloads\\PORQ_evocativeVideoTask_LIWCOutput (1).csv")

# %%
#Dropping WC since prolly not useful


from sklearn import preprocessing
Bad = []
y = file.drop(['WC'],axis=1)
for (columnName, columnData) in y.iteritems():
     for item in columnData:
          if(isinstance(item,int) and item>100):
               Bad.append(columnName)
                
for item in Bad:
    float_array = y[item].values.astype(float)
    X_scaled = preprocessing.scale(float_array)
    y[item]= pd.DataFrame(X_scaled)

# %%
num_colums = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerical_columns = list(y.select_dtypes(include=num_colums).columns)
y = y[numerical_columns]

# %%
correlated_features = set()
correlation_matrix = y.corr()

# %%
correlated_features
# Out:
# set()

# %%
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            print(i)
            correlated_features.add(colname)
# Out:
# 67
# 79
# 83
# 83

# %%
correlation_matrix
# Out:
#            Segment  Analytic     Clout  Authentic      Tone       WPS  \
# Segment        NaN       NaN       NaN        NaN       NaN       NaN
# Analytic       NaN  1.000000  0.385430  -0.204375 -0.092538  0.142131
# Clout          NaN  0.385430  1.000000  -0.639631 -0.072392  0.145378
# Authentic      NaN -0.204375 -0.639631   1.000000  0.007889 -0.043676
# Tone           NaN -0.092538 -0.072392   0.007889  1.000000 -0.077959
# ...            ...       ...       ...        ...       ...       ...
# Dash           NaN  0.005213  0.007491  -0.019871 -0.017178  0.140321
# Quote          NaN -0.027935  0.002628  -0.016271  0.007368 -0.003513
# Apostro        NaN -0.396948 -0.161364   0.101903  0.034592 -0.178953
# Parenth        NaN       NaN       NaN        NaN       NaN       NaN
# OtherP         NaN  0.027841 -0.069907   0.004953  0.073582 -0.111503
#
#              Sixltr       Dic  function   pronoun  ...     Comma     Colon  \
# Segment         NaN       NaN       NaN       NaN  ...       NaN       NaN
# Analytic   0.133521 -0.387450 -0.402254 -0.764972  ... -0.016877  0.007455
# Clout     -0.000491 -0.153681 -0.057258 -0.264741  ... -0.053502 -0.040689
# Authentic -0.006348  0.228555  0.075689  0.203748  ... -0.033482 -0.010919
# Tone       0.008206  0.112365 -0.097925  0.024142  ...  0.063879  0.005531
# ...             ...       ...       ...       ...  ...       ...       ...
# Dash      -0.051391 -0.009279  0.089293  0.048507  ...  0.009355 -0.112915
# Quote     -0.090998  0.035315  0.016621  0.037995  ... -0.018683  0.000303
# Apostro   -0.071163  0.140065  0.250055  0.338655  ... -0.050503 -0.015356
# Parenth         NaN       NaN       NaN       NaN  ...       NaN       NaN
# OtherP     0.126540 -0.281270 -0.303784 -0.089326  ...  0.131562  0.671532
#
#               SemiC     QMark  Exclam      Dash     Quote   Apostro  Parenth  \
# Segment         NaN       NaN     NaN       NaN       NaN       NaN      NaN
# Analytic  -0.002748 -0.093017     NaN  0.005213 -0.027935 -0.396948      NaN
# Clout     -0.019695 -0.010004     NaN  0.007491  0.002628 -0.161364      NaN
# Authentic -0.004480  0.018928     NaN -0.019871 -0.016271  0.101903      NaN
# Tone       0.014070 -0.030138     NaN -0.017178  0.007368  0.034592      NaN
# ...             ...       ...     ...       ...       ...       ...      ...
# Dash      -0.091282  0.004088     NaN  1.000000 -0.073474 -0.034470      NaN
# Quote      0.001560  0.002436     NaN -0.073474  1.000000  0.014261      NaN
# Apostro    0.051684  0.089892     NaN -0.034470  0.014261  1.000000      NaN
# Parenth         NaN       NaN     NaN       NaN       NaN       NaN      NaN
# OtherP     0.013649 -0.005328     NaN -0.142850  0.009570 -0.014626      NaN
#
#              OtherP
# Segment         NaN
# Analytic   0.027841
# Clout     -0.069907
# Authentic  0.004953
# Tone       0.073582
# ...             ...
# Dash      -0.142850
# Quote      0.009570
# Apostro   -0.014626
# Parenth         NaN
# OtherP     1.000000
#
# [93 rows x 93 columns]

# %%
y.drop(labels=correlated_features, axis=1, inplace=True)

# %%
from sklearn.cluster import KMeans 
clusters = 7
  
kmeans = KMeans(n_clusters = clusters) 
kmeans.fit(y)
# Out:
# KMeans(n_clusters=7)

# %%
kmeans._labels
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-89a02654d343> in <module>
# ----> 1 kmeans._labels
#
# AttributeError: 'KMeans' object has no attribute '_labels'
